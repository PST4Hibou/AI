# %%
import torch
import torchaudio
from datasets import load_dataset, DatasetDict
from tqdm import tqdm
import numpy as np

SEED = 42
SAMPLE_RATE = 16000

# %%
# Load dataset
ds = load_dataset("Usernameeeeee/df_462700_2")
ds_split = ds["train"].train_test_split(test_size=0.3, seed=SEED, shuffle=True)
test_and_valid = ds_split["test"].train_test_split(test_size=0.5, seed=SEED, shuffle=True)


ds = DatasetDict({
    "train": ds_split["train"],
    "valid": test_and_valid["train"],
    "test": test_and_valid["test"],
})

# %%
# Define transforms
mel_transform = torchaudio.transforms.MelSpectrogram(
    sample_rate=SAMPLE_RATE,
    n_fft=2048,
    hop_length=256,
    n_mels=64,
)
db_transform = torchaudio.transforms.AmplitudeToDB()

def preprocess_split(split_data, split_name):
    """Preprocess audio to mel spectrograms"""
    processed = []

    for item in tqdm(split_data, desc=f"Processing {split_name}"):
        waveform = torch.tensor(item["audio"]).float()

        # Convert to mono
        if waveform.ndim > 1:
            waveform = waveform.mean(dim=0)

        # Compute mel spectrogram
        mel = mel_transform(waveform)
        mel_db = db_transform(mel)

        processed.append({
            "mel_spectrogram": mel_db.numpy(),
            "label": item["label"]
        })

    return processed

# Process all splits
print("Preprocessing dataset...")
processed_ds = {
    "train": preprocess_split(ds["train"], "train"),
    "valid": preprocess_split(ds["valid"], "valid"),
    "test": preprocess_split(ds["test"], "test"),
}
# Out:
# Preprocessing dataset...
# Processing train:   2%|▏         | 6285/323890 [00:20<17:32, 301.73it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 35
#      32 # Process all splits
#      33 print("Preprocessing dataset...")
#      34 processed_ds = {
# ---> 35     "train": preprocess_split(ds["train"], "train"),
#      36     "valid": preprocess_split(ds["valid"], "valid"),
#      37     "test": preprocess_split(ds["test"], "test"),
#      38 }
#
# Cell In[22], line 15, in preprocess_split(split_data, split_name)
#      12 processed = []
#      14 for item in tqdm(split_data, desc=f"Processing {split_name}"):
# ---> 15     waveform = torch.tensor(item["audio"]).float()
#      17     # Convert to mono
#      18     if waveform.ndim > 1:
#
# KeyboardInterrupt:
